# %%
print("Hello")

# %%
emp_data=[(100,'Eswar',20000),
          (101,'Gowtham',23000),
          (102,'Harish',25000),
          (103,'NItin',27000),
          ]
emp_columns=["EmpId","EmpName","Salary"]
emp_df=spark.createDataFrame(data=emp_data,schema=emp_columns)
display(emp_df);

# %%
emp_df.show();

# %%
from pyspark.sql import functions as f
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

stu_data=[(
          100,'vishnu',1,'A'),
          (101,'Ravi',2,'B'),
          (102,'Rajesh',3,'c'),
          (103,'NItin',3,'c'),
          (104,'Kishore',2,'B'),
         
]
schema=StructType([
    StructField('StuId',IntegerType(),True),
    StructField('StuName',StringType(),True),
        StructField('class',IntegerType(),True),
    StructField('Session',StringType(),True),
])
stu_df=spark.createDataFrame(data=stu_data,schema=schema)
display(stu_df);
